# %%
from __future__ import division, print_function, absolute_import
import tensorboard
import tflearn

n = 5

# Real-time data preprocessing
img_prep = tflearn.ImagePreprocessing()
img_prep.add_featurewise_zero_center(per_channel=True, mean=[0.53990436 , 0.4405486  , 0.39328504])

# Real-time data augmentation
img_aug = tflearn.ImageAugmentation()
img_aug.add_random_flip_leftright()
img_aug.add_random_crop([49, 49], padding=4)

# Building Residual Network
net = tflearn.input_data(shape=[None, 49, 49, 3],
                         data_preprocessing=img_prep,
                         data_augmentation=img_aug)
net = tflearn.conv_2d(net, 16, 3, regularizer='L2', weight_decay=0.0001)
net = tflearn.resnext_block(net, n, 16, 32)
net = tflearn.resnext_block(net, 1, 32, 32, downsample=True)
net = tflearn.resnext_block(net, n-1, 32, 32)
net = tflearn.resnext_block(net, 1, 64, 32, downsample=True)
net = tflearn.resnext_block(net, n-1, 64, 32)
net = tflearn.batch_normalization(net)
net = tflearn.activation(net, 'relu')
net = tflearn.global_avg_pool(net)
# Regression
net = tflearn.fully_connected(net, 11, activation='softmax')
opt = tflearn.Momentum(0.1, lr_decay=0.1, decay_step=32000, staircase=True)
net = tflearn.regression(net, optimizer=opt,
                         loss='categorical_crossentropy')
# Training
model = tflearn.DNN(net, checkpoint_path='Snapshots/model_resnext',
                    max_checkpoints=10, tensorboard_verbose=0, tensorboard_dir='Logs/',
                    clip_gradients=0.)
model.load('AffectNet_pretrained_model/model_resnext-96000')
# Out:
# curses is not supported on this machine (please install/reinstall curses for an optimal experience)
# WARNING:tensorflow:From C:\Users\nishq\Anaconda3\envs\tfdeeplearning\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\nishq\Anaconda3\envs\tfdeeplearning\lib\site-packages\tflearn\initializations.py:119: UniformUnitScaling.__init__ (from tensorflow.python.ops.init_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.initializers.variance_scaling instead with distribution=uniform to get equivalent behavior.
# WARNING:tensorflow:From C:\Users\nishq\Anaconda3\envs\tfdeeplearning\lib\site-packages\tflearn\objectives.py:66: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From C:\Users\nishq\Anaconda3\envs\tfdeeplearning\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
import glob
import pandas as pd
import operator
import tensorflow as tf 
import numpy as np


output_dict = {}

output_dict['Filepath'] = []
output_dict['Label'] = []
output_dict['Neutral Confidence'] = []
output_dict['Happy Confidence'] = []
output_dict['Sad Confidence'] = []
output_dict['Surprise Confidence'] = []
output_dict['Fear Confidence'] = []
output_dict['Disgust Confidence'] = []
output_dict['Anger Confidence'] = []
output_dict['Contempt Confidence'] = []
output_dict['None Confidence'] = []
output_dict['Uncertain Confidence'] = []
output_dict['No-Face Confidence']  = []
sess= tf.Session()

html = """<!DOCTYPE html> 
<html>

<head>
    <link rel="stylesheet" href="style.css">
    <title>AffectNet Pretrained Model Testing</title>
</head>
<body>
    <center>
        <h1>AffectNet Pretrained Model testing</h1>
    </center>"""



# ----------------------------------------------------------------------------- Get all happy-labelled images
html+= """<center>
        <h1>Smiling</h1>
    </center>
    
    <table align="center" >

        <tr>
            
            <th align="center" width=200 >Photo</th>
            <th align="center" width=200 >Emotion</th>
            <th align="center" width=200 >Emotion Confidence</th>
            
        </tr>"""


for filepath in glob.iglob('Datasets/FEI_frontal/*b.jpg'):
    print(filepath)
    
    img = tf.read_file(filepath)
    img = tf.image.decode_jpeg(img, channels=3)
    img.set_shape([None, None, 3])
    img = tf.image.resize_images(img, (49, 49))
    img = img.eval(session=sess) # convert to numpy array
    img = np.expand_dims(img, 0) # make 'batch' of 1
    img = img/255.0
    
    prediction = model.predict(img)
    
    emotion_dict = {}
    emotion_dict['Neutral'] = prediction[0][0]
    emotion_dict['Happy'] = prediction[0][1]
    emotion_dict['Sad'] = prediction[0][2]
    emotion_dict['Surprise'] = prediction[0][3]
    emotion_dict['Fear'] = prediction[0][4]
    emotion_dict['Disgust'] = prediction[0][5]
    emotion_dict['Anger'] = prediction[0][6]
    emotion_dict['Contempt'] = prediction[0][7]
    emotion_dict['None'] = prediction[0][8]
    emotion_dict['Uncertain'] = prediction[0][9]
    emotion_dict['No-Face'] = prediction[0][10]
    
    output_dict['Filepath'].append(filepath)
    output_dict['Label'].append('Happy')
    output_dict['Neutral Confidence'].append(prediction[0][0])
    output_dict['Happy Confidence'].append(prediction[0][1])
    output_dict['Sad Confidence'].append(prediction[0][2])
    output_dict['Surprise Confidence'].append(prediction[0][3])
    output_dict['Fear Confidence'].append(prediction[0][4])
    output_dict['Disgust Confidence'].append(prediction[0][5])
    output_dict['Anger Confidence'].append(prediction[0][6])
    output_dict['Contempt Confidence'].append(prediction[0][7])
    output_dict['None Confidence'].append(prediction[0][8])
    output_dict['Uncertain Confidence'].append(prediction[0][9])
    output_dict['No-Face Confidence'].append(prediction[0][10]) 
    
    emotion = str(max(emotion_dict.items(), key=operator.itemgetter(1))[0])
    emotion_confidence = max(emotion_dict.items(), key=operator.itemgetter(1))[1] *100
    
    html+= """<tr align="center">

                <td><img src="""+'"'+str(filepath)+'"'+""" alt="" border=3 height=200 width=200></img></td>
                <td align="center" height=200 width=200 >"""+emotion+"""</td>
                <td align="center" height=200 width=200 >"""+str(round(emotion_confidence))+"""%</td>

            </tr>"""
    print(emotion)
    print(emotion_confidence)
    
html+="""</table>"""


# ----------------------------------------------------------------------------- Get all neutral-labelled images

html+= """<center>
        <h1>Neutral</h1>
    </center>
    
    <table align="center" >

        <tr>
            
            <th align="center" width=200 >Photo</th>
            <th align="center" width=200 >Emotion</th>
            <th align="center" width=200 >Emotion Confidence</th>
            
        </tr>"""


for filepath in glob.iglob('Datasets/FEI_frontal/*a.jpg'):
    print(filepath)
    
    img = tf.read_file(filepath)
    img = tf.image.decode_jpeg(img, channels=3)
    img.set_shape([None, None, 3])
    img = tf.image.resize_images(img, (49, 49))
    img = img.eval(session=sess) # convert to numpy array
    img = np.expand_dims(img, 0) # make 'batch' of 1
    img = img/255.0
    
    prediction = model.predict(img)
    
    emotion_dict = {}
    emotion_dict['Neutral'] = prediction[0][0]
    emotion_dict['Happy'] = prediction[0][1]
    emotion_dict['Sad'] = prediction[0][2]
    emotion_dict['Surprise'] = prediction[0][3]
    emotion_dict['Fear'] = prediction[0][4]
    emotion_dict['Disgust'] = prediction[0][5]
    emotion_dict['Anger'] = prediction[0][6]
    emotion_dict['Contempt'] = prediction[0][7]
    emotion_dict['None'] = prediction[0][8]
    emotion_dict['Uncertain'] = prediction[0][9]
    emotion_dict['No-Face'] = prediction[0][10]
    
    output_dict['Filepath'].append(filepath)
    output_dict['Label'].append('Neutral')
    output_dict['Neutral Confidence'].append(prediction[0][0])
    output_dict['Happy Confidence'].append(prediction[0][1])
    output_dict['Sad Confidence'].append(prediction[0][2])
    output_dict['Surprise Confidence'].append(prediction[0][3])
    output_dict['Fear Confidence'].append(prediction[0][4])
    output_dict['Disgust Confidence'].append(prediction[0][5])
    output_dict['Anger Confidence'].append(prediction[0][6])
    output_dict['Contempt Confidence'].append(prediction[0][7])
    output_dict['None Confidence'].append(prediction[0][8])
    output_dict['Uncertain Confidence'].append(prediction[0][9])
    output_dict['No-Face Confidence'].append(prediction[0][10]) 
    
    emotion = str(max(emotion_dict.items(), key=operator.itemgetter(1))[0])
    emotion_confidence = max(emotion_dict.items(), key=operator.itemgetter(1))[1] *100
    
    html+= """<tr align="center">

                <td><img src="""+'"'+str(filepath)+'"'+""" alt="" border=3 height=200 width=200></img></td>
                <td align="center" height=200 width=200 >"""+emotion+"""</td>
                <td align="center" height=200 width=200 >"""+str(round(emotion_confidence))+"""%</td>

            </tr>"""
    print(emotion)
    print(emotion_confidence)
    
html+="""</table>"""

html+="""</body>"""
Html_file= open("AffectNet_FEI_observation_test_output.html","w",encoding="utf-8")
Html_file.write(html)
Html_file.close()

df = pd.DataFrame(output_dict)
df.to_csv('AffectNet_FEI_raw_test_data_output.csv')
# Out:
# FEI_frontal\100b.jpg
# Happy
# 96.85356020927429
# FEI_frontal\101b.jpg
# Happy
# 75.50677061080933
# FEI_frontal\102b.jpg
# Happy
# 73.7402856349945
# FEI_frontal\103b.jpg
# Happy
# 97.52349257469177
# FEI_frontal\104b.jpg
# Happy
# 73.36391806602478
# FEI_frontal\105b.jpg
# Happy
# 98.00311326980591
# FEI_frontal\106b.jpg
# Happy
# 95.81490159034729
# FEI_frontal\107b.jpg
# Happy
# 89.09709453582764
# FEI_frontal\108b.jpg
# Happy
# 90.39613008499146
# FEI_frontal\109b.jpg
# Happy
# 79.63216304779053
# FEI_frontal\10b.jpg
# Happy
# 79.27834391593933
# FEI_frontal\110b.jpg
# Happy
# 58.80449414253235
# FEI_frontal\111b.jpg
# Happy
# 52.68571376800537
# FEI_frontal\112b.jpg
# Happy
# 90.76911807060242
# FEI_frontal\113b.jpg
# Happy
# 90.55947065353394
# FEI_frontal\114b.jpg
# Happy
# 69.62067484855652
# FEI_frontal\115b.jpg
# Happy
# 88.66569399833679
# FEI_frontal\116b.jpg
# Happy
# 80.88290095329285
# FEI_frontal\117b.jpg
# Happy
# 85.58138608932495
# FEI_frontal\118b.jpg
# Happy
# 88.8358473777771
# FEI_frontal\119b.jpg
# Happy
# 90.72123765945435
# FEI_frontal\11b.jpg
# Happy
# 61.36311888694763
# FEI_frontal\120b.jpg
# Happy
# 86.07479929924011
# FEI_frontal\121b.jpg
# Happy
# 75.22717118263245
# FEI_frontal\122b.jpg
# Happy
# 94.10638213157654
# FEI_frontal\123b.jpg
# Happy
# 80.53746223449707
# FEI_frontal\124b.jpg
# Happy
# 88.48743438720703
# FEI_frontal\125b.jpg
# Happy
# 98.5272228717804
# FEI_frontal\126b.jpg
# Happy
# 73.81922006607056
# FEI_frontal\127b.jpg
# Happy
# 87.75546550750732
# FEI_frontal\128b.jpg
# Happy
# 68.88186931610107
# FEI_frontal\129b.jpg
# Happy
# 96.46414518356323
# FEI_frontal\12b.jpg
# Happy
# 92.17313528060913
# FEI_frontal\130b.jpg
# Happy
# 73.5289990901947
# FEI_frontal\131b.jpg
# Happy
# 87.09388971328735
# FEI_frontal\132b.jpg
# No-Face
# 73.22331070899963
# FEI_frontal\133b.jpg
# No-Face
# 50.74867606163025
# FEI_frontal\134b.jpg
# Happy
# 61.92261576652527
# FEI_frontal\135b.jpg
# Happy
# 85.30697226524353
# FEI_frontal\136b.jpg
# Happy
# 54.46672439575195
# FEI_frontal\137b.jpg
# Happy
# 85.60004830360413
# FEI_frontal\138b.jpg
# Happy
# 94.93219256401062
# FEI_frontal\139b.jpg
# Happy
# 73.33047389984131
# FEI_frontal\13b.jpg
# Happy
# 91.72714352607727
# FEI_frontal\140b.jpg
# Happy
# 60.25983691215515
# FEI_frontal\141b.jpg
# Happy
# 93.71514916419983
# FEI_frontal\142b.jpg
# No-Face
# 83.2562804222107
# FEI_frontal\143b.jpg
# Happy
# 76.0307788848877
# FEI_frontal\144b.jpg
# Happy
# 81.4933717250824
# FEI_frontal\145b.jpg
# Happy
# 59.62541699409485
# FEI_frontal\146b.jpg
# Happy
# 93.81528496742249
# FEI_frontal\147b.jpg
# Happy
# 87.12286949157715
# FEI_frontal\148b.jpg
# Happy
# 42.59229898452759
# FEI_frontal\149b.jpg
# Happy
# 95.01161575317383
# FEI_frontal\14b.jpg
# Happy
# 70.8662748336792
# FEI_frontal\150b.jpg
# Happy
# 97.11251258850098
# FEI_frontal\151b.jpg
# Happy
# 73.89054894447327
# FEI_frontal\152b.jpg
# Happy
# 90.73103666305542
# FEI_frontal\153b.jpg
# Happy
# 84.40807461738586
# FEI_frontal\154b.jpg
# Happy
# 70.06590366363525
# FEI_frontal\155b.jpg
# Happy
# 94.32892203330994
# FEI_frontal\156b.jpg
# Happy
# 61.540043354034424
# FEI_frontal\157b.jpg
# Happy
# 84.38829183578491
# FEI_frontal\158b.jpg
# Happy
# 97.0487892627716
# FEI_frontal\159b.jpg
# Happy
# 90.94796180725098
# FEI_frontal\15b.jpg
# Happy
# 83.50186347961426
# FEI_frontal\160b.jpg
# Happy
# 83.26951265335083
# FEI_frontal\161b.jpg
# Happy
# 61.692482233047485
# FEI_frontal\162b.jpg
# Happy
# 93.27223300933838
# FEI_frontal\163b.jpg
# Happy
# 88.24115991592407
# FEI_frontal\164b.jpg
# Happy
# 40.61784744262695
# FEI_frontal\165b.jpg
# Happy
# 96.5004563331604
# FEI_frontal\166b.jpg
# Happy
# 77.58501172065735
# FEI_frontal\167b.jpg
# Happy
# 95.47476768493652
# FEI_frontal\168b.jpg
# Happy
# 95.71080803871155
# FEI_frontal\169b.jpg
# Happy
# 92.9508924484253
# FEI_frontal\16b.jpg
# Happy
# 78.1145989894867
# FEI_frontal\170b.jpg
# Happy
# 81.25782012939453
# FEI_frontal\171b.jpg
# Happy
# 88.5284423828125
# FEI_frontal\172b.jpg
# Happy
# 98.3456552028656
# FEI_frontal\173b.jpg
# No-Face
# 70.68724036216736
# FEI_frontal\174b.jpg
# Happy
# 95.8324134349823
# FEI_frontal\175b.jpg
# Happy
# 69.19939517974854
# FEI_frontal\176b.jpg
# Happy
# 94.17601227760315
# FEI_frontal\177b.jpg
# Happy
# 87.96879053115845
# FEI_frontal\178b.jpg
# Happy
# 90.40294885635376
# FEI_frontal\179b.jpg
# Happy
# 96.5882658958435
# FEI_frontal\17b.jpg
# Happy
# 57.877832651138306
# FEI_frontal\180b.jpg
# Happy
# 76.81147456169128
# FEI_frontal\181b.jpg
# Happy
# 93.2496726512909
# FEI_frontal\182b.jpg
# Happy
# 95.87299227714539
# FEI_frontal\183b.jpg
# Happy
# 98.04906249046326
# FEI_frontal\184b.jpg
# Happy
# 94.95174884796143
# FEI_frontal\185b.jpg
# Happy
# 83.81617665290833
# FEI_frontal\186b.jpg
# Happy
# 65.84709882736206
# FEI_frontal\187b.jpg
# Happy
# 90.40571451187134
# FEI_frontal\188b.jpg
# Happy
# 77.73576378822327
# FEI_frontal\189b.jpg
# Happy
# 67.82256364822388
# FEI_frontal\18b.jpg
# Happy
# 94.11550164222717
# FEI_frontal\190b.jpg
# Happy
# 84.16450619697571
# FEI_frontal\191b.jpg
# Happy
# 86.27429008483887
# FEI_frontal\192b.jpg
# Happy
# 85.87263822555542
# FEI_frontal\193b.jpg
# Happy
# 94.98608708381653
# FEI_frontal\194b.jpg
# Happy
# 46.9483345746994
# FEI_frontal\195b.jpg
# Happy
# 51.26386880874634
# FEI_frontal\196b.jpg
# Happy
# 98.22489023208618
# FEI_frontal\197b.jpg
# Happy
# 96.39295935630798
# FEI_frontal\198b.jpg
# Happy
# 88.95403146743774
# FEI_frontal\199b.jpg
# Happy
# 94.91605758666992
# FEI_frontal\19b.jpg
# Happy
# 64.41952586174011
# FEI_frontal\1b.jpg
# Happy
# 71.73512578010559
# FEI_frontal\200b.jpg
# Happy
# 89.19972777366638
# FEI_frontal\20b.jpg
# Happy
# 95.15589475631714
# FEI_frontal\21b.jpg
# Happy
# 84.09234285354614
# FEI_frontal\22b.jpg
# Happy
# 57.79547095298767
# FEI_frontal\23b.jpg
# Happy
# 75.45138597488403
# FEI_frontal\24b.jpg
# Happy
# 88.22279572486877
# FEI_frontal\25b.jpg
# Happy
# 82.48234391212463
# FEI_frontal\26b.jpg
# Happy
# 68.14301609992981
# FEI_frontal\27b.jpg
# Happy
# 87.89010643959045
# FEI_frontal\28b.jpg
# Happy
# 97.27572202682495
# FEI_frontal\29b.jpg
# Happy
# 60.39007902145386
# FEI_frontal\2b.jpg
# Happy
# 68.92029047012329
# FEI_frontal\30b.jpg
# Happy
# 68.10932159423828
# FEI_frontal\31b.jpg
# Happy
# 83.34652781486511
# FEI_frontal\32b.jpg
# Happy
# 79.90431189537048
# FEI_frontal\33b.jpg
# Happy
# 94.02633309364319
# FEI_frontal\34b.jpg
# Happy
# 93.7999963760376
# FEI_frontal\35b.jpg
# Happy
# 81.49702548980713
# FEI_frontal\36b.jpg
# Happy
# 69.38926577568054
# FEI_frontal\37b.jpg
# No-Face
# 66.99384450912476
# FEI_frontal\38b.jpg
# Happy
# 94.88574862480164
# FEI_frontal\39b.jpg
# No-Face
# 65.6722366809845
# FEI_frontal\3b.jpg
# Happy
# 89.23459649085999
# FEI_frontal\40b.jpg
# Happy
# 82.81694650650024
# FEI_frontal\41b.jpg
# No-Face
# 50.325119495391846
# FEI_frontal\42b.jpg
# Happy
# 97.76050448417664
# FEI_frontal\43b.jpg
# Happy
# 85.62886714935303
# FEI_frontal\44b.jpg
# Happy
# 79.38712239265442
# FEI_frontal\45b.jpg
# Happy
# 88.40670585632324
# FEI_frontal\46b.jpg
# Happy
# 73.85116815567017
# FEI_frontal\47b.jpg
# Happy
# 88.7189269065857
# FEI_frontal\48b.jpg
# Happy
# 98.45929741859436
# FEI_frontal\49b.jpg
# Happy
# 88.4848415851593
# FEI_frontal\4b.jpg
# Happy
# 88.29022645950317
# FEI_frontal\50b.jpg
# Happy
# 93.1406557559967
# FEI_frontal\51b.jpg
# Happy
# 93.8509464263916
# FEI_frontal\52b.jpg
# Happy
# 65.91165661811829
# FEI_frontal\53b.jpg
# Happy
# 74.40143823623657
# FEI_frontal\54b.jpg
# Happy
# 90.38683772087097
# FEI_frontal\55b.jpg
# No-Face
# 50.65958499908447
# FEI_frontal\56b.jpg
# Happy
# 83.57328772544861
# FEI_frontal\57b.jpg
# Happy
# 78.73693704605103
# FEI_frontal\58b.jpg
# Happy
# 73.23699593544006
# FEI_frontal\59b.jpg
# Happy
# 74.58856105804443
# FEI_frontal\5b.jpg
# Happy
# 87.28921413421631
# FEI_frontal\60b.jpg
# Happy
# 91.27933979034424
# FEI_frontal\61b.jpg
# Happy
# 66.49472713470459
# FEI_frontal\62b.jpg
# Happy
# 93.92736554145813
# FEI_frontal\63b.jpg
# Happy
# 88.22917938232422
# FEI_frontal\64b.jpg
# No-Face
# 51.184892654418945
# FEI_frontal\65b.jpg
# Happy
# 77.01408267021179
# FEI_frontal\66b.jpg
# Happy
# 65.69434404373169
# FEI_frontal\67b.jpg
# Happy
# 70.37907838821411
# FEI_frontal\68b.jpg
# Happy
# 80.90302348136902
# FEI_frontal\69b.jpg
# Happy
# 88.82213830947876
# FEI_frontal\6b.jpg
# Happy
# 55.73781728744507
# FEI_frontal\70b.jpg
# Happy
# 84.00235772132874
# FEI_frontal\71b.jpg
# Happy
# 83.49737524986267
# FEI_frontal\72b.jpg
# Happy
# 87.13827133178711
# FEI_frontal\73b.jpg
# Happy
# 50.77993869781494
# FEI_frontal\74b.jpg
# Happy
# 68.6402678489685
# FEI_frontal\75b.jpg
# Happy
# 64.43172097206116
# FEI_frontal\76b.jpg
# Happy
# 93.93320083618164
# FEI_frontal\77b.jpg
# Happy
# 74.59442019462585
# FEI_frontal\78b.jpg
# Happy
# 88.74356746673584
# FEI_frontal\79b.jpg
# Happy
# 63.87508511543274
# FEI_frontal\7b.jpg
# Happy
# 70.19566297531128
# FEI_frontal\80b.jpg
# Happy
# 89.27982449531555
# FEI_frontal\81b.jpg
# Happy
# 95.16453146934509
# FEI_frontal\82b.jpg
# Happy
# 60.67609190940857
# FEI_frontal\83b.jpg
# Happy
# 87.68041729927063
# FEI_frontal\84b.jpg
# No-Face
# 50.425297021865845
# FEI_frontal\85b.jpg
# Happy
# 94.62194442749023
# FEI_frontal\86b.jpg
# Happy
# 59.2267632484436
# FEI_frontal\87b.jpg
# No-Face
# 64.37748074531555
# FEI_frontal\88b.jpg
# Happy
# 85.24803519248962
# FEI_frontal\89b.jpg
# Happy
# 95.93432545661926
# FEI_frontal\8b.jpg
# Happy
# 93.13724637031555
# FEI_frontal\90b.jpg
# Happy
# 92.30022430419922
# FEI_frontal\91b.jpg
# Happy
# 91.47948026657104
# FEI_frontal\92b.jpg
# Happy
# 68.68836283683777
# FEI_frontal\93b.jpg
# Happy
# 89.43386673927307
# FEI_frontal\94b.jpg
# Happy
# 74.8525857925415
# FEI_frontal\95b.jpg
# Happy
# 76.80295705795288
# FEI_frontal\96b.jpg
# Happy
# 96.99903130531311
# FEI_frontal\97b.jpg
# Happy
# 95.19208073616028
# FEI_frontal\98b.jpg
# Happy
# 91.60079956054688
# FEI_frontal\99b.jpg
# Happy
# 90.70939421653748
# FEI_frontal\9b.jpg
# Happy
# 94.30067539215088
# FEI_frontal\100a.jpg
# Neutral
# 37.98264563083649
# FEI_frontal\101a.jpg
# Sad
# 69.31707859039307
# FEI_frontal\102a.jpg
# No-Face
# 49.915966391563416
# FEI_frontal\103a.jpg
# Happy
# 65.71638584136963
# FEI_frontal\104a.jpg
# No-Face
# 47.189512848854065
# FEI_frontal\105a.jpg
# Neutral
# 54.897648096084595
# FEI_frontal\106a.jpg
# Neutral
# 36.97158098220825
# FEI_frontal\107a.jpg
# Neutral
# 45.815032720565796
# FEI_frontal\108a.jpg
# Sad
# 32.69011974334717
# FEI_frontal\109a.jpg
# Neutral
# 65.57711362838745
# FEI_frontal\10a.jpg
# Neutral
# 31.87999725341797
# FEI_frontal\110a.jpg
# Neutral
# 43.32559406757355
# FEI_frontal\111a.jpg
# No-Face
# 46.25625014305115
# FEI_frontal\112a.jpg
# No-Face
# 36.05320155620575
# FEI_frontal\113a.jpg
# Neutral
# 55.390363931655884
# FEI_frontal\114a.jpg
# No-Face
# 41.860201954841614
# FEI_frontal\115a.jpg
# Neutral
# 48.603132367134094
# FEI_frontal\116a.jpg
# No-Face
# 33.68646204471588
# FEI_frontal\117a.jpg
# Neutral
# 32.537972927093506
# FEI_frontal\118a.jpg
# Happy
# 37.53487765789032
# FEI_frontal\119a.jpg
# Neutral
# 51.958250999450684
# FEI_frontal\11a.jpg
# Happy
# 22.901085019111633
# FEI_frontal\120a.jpg
# Neutral
# 38.62142860889435
# FEI_frontal\121a.jpg
# Neutral
# 50.19012093544006
# FEI_frontal\122a.jpg
# Neutral
# 49.26524460315704
# FEI_frontal\123a.jpg
# Happy
# 65.93195796012878
# FEI_frontal\124a.jpg
# Happy
# 46.410784125328064
# FEI_frontal\125a.jpg
# Happy
# 36.55686378479004
# FEI_frontal\126a.jpg
# Sad
# 54.479557275772095
# FEI_frontal\127a.jpg
# Neutral
# 58.98498296737671
# FEI_frontal\128a.jpg
# No-Face
# 42.39114820957184
# FEI_frontal\129a.jpg
# Neutral
# 47.98063933849335
# FEI_frontal\12a.jpg
# Happy
# 67.14909672737122
# FEI_frontal\130a.jpg
# No-Face
# 40.01522362232208
# FEI_frontal\131a.jpg
# Sad
# 29.844507575035095
# FEI_frontal\132a.jpg
# Happy
# 28.78963053226471
# FEI_frontal\133a.jpg
# Neutral
# 41.11052453517914
# FEI_frontal\134a.jpg
# No-Face
# 39.43702280521393
# FEI_frontal\135a.jpg
# Neutral
# 52.75983214378357
# FEI_frontal\136a.jpg
# Happy
# 65.79009294509888
# FEI_frontal\137a.jpg
# Happy
# 39.40822780132294
# FEI_frontal\138a.jpg
# Neutral
# 65.37495255470276
# FEI_frontal\139a.jpg
# No-Face
# 46.9158798456192
# FEI_frontal\13a.jpg
# Happy
# 62.103116512298584
# FEI_frontal\140a.jpg
# Neutral
# 55.64185380935669
# FEI_frontal\141a.jpg
# Neutral
# 36.11535131931305
# FEI_frontal\142a.jpg
# No-Face
# 51.045435667037964
# FEI_frontal\143a.jpg
# Sad
# 42.654117941856384
# FEI_frontal\144a.jpg
# Neutral
# 53.34104895591736
# FEI_frontal\145a.jpg
# No-Face
# 29.257160425186157
# FEI_frontal\146a.jpg
# Neutral
# 56.54014348983765
# FEI_frontal\147a.jpg
# No-Face
# 38.756123185157776
# FEI_frontal\148a.jpg
# Neutral
# 59.671127796173096
# FEI_frontal\149a.jpg
# Neutral
# 40.38533568382263
# FEI_frontal\14a.jpg
# Happy
# 78.79594564437866
# FEI_frontal\150a.jpg
# Neutral
# 36.26028895378113
# FEI_frontal\151a.jpg
# Neutral
# 52.22436189651489
# FEI_frontal\152a.jpg
# Happy
# 31.300583481788635
# FEI_frontal\153a.jpg
# Neutral
# 61.96833848953247
# FEI_frontal\154a.jpg
# Neutral
# 43.46538782119751
# FEI_frontal\155a.jpg
# Happy
# 42.86530315876007
# FEI_frontal\156a.jpg
# Happy
# 27.04465091228485
# FEI_frontal\157a.jpg
# Neutral
# 62.28721737861633
# FEI_frontal\158a.jpg
# Neutral
# 61.98017597198486
# FEI_frontal\159a.jpg
# Neutral
# 60.091376304626465
# FEI_frontal\15a.jpg
# Neutral
# 45.908862352371216
# FEI_frontal\160a.jpg
# Happy
# 59.261733293533325
# FEI_frontal\161a.jpg
# Neutral
# 53.21173667907715
# FEI_frontal\162a.jpg
# Happy
# 64.04500007629395
# FEI_frontal\163a.jpg
# Neutral
# 41.36872589588165
# FEI_frontal\164a.jpg
# No-Face
# 49.828097224235535
# FEI_frontal\165a.jpg
# Happy
# 36.740776896476746
# FEI_frontal\166a.jpg
# No-Face
# 54.611754417419434
# FEI_frontal\167a.jpg
# No-Face
# 49.78817105293274
# FEI_frontal\168a.jpg
# Happy
# 65.98451137542725
# FEI_frontal\169a.jpg
# Neutral
# 45.828765630722046
# FEI_frontal\16a.jpg
# Neutral
# 39.77341949939728
# FEI_frontal\170a.jpg
# Neutral
# 52.696919441223145
# FEI_frontal\171a.jpg
# Anger
# 38.46839368343353
# FEI_frontal\172a.jpg
# Happy
# 52.99803018569946
# FEI_frontal\173a.jpg
# Neutral
# 30.827972292900085
# FEI_frontal\174a.jpg
# Happy
# 34.197720885276794
# FEI_frontal\175a.jpg
# No-Face
# 49.01524484157562
# FEI_frontal\176a.jpg
# Neutral
# 45.12428939342499
# FEI_frontal\177a.jpg
# Happy
# 47.6506769657135
# FEI_frontal\178a.jpg
# Neutral
# 45.86385786533356
# FEI_frontal\179a.jpg
# Neutral
# 60.76576113700867
# FEI_frontal\17a.jpg
# No-Face
# 40.48285484313965
# FEI_frontal\180a.jpg
# Neutral
# 31.688490509986877
# FEI_frontal\181a.jpg
# Neutral
# 32.61019289493561
# FEI_frontal\182a.jpg
# Neutral
# 52.08325982093811
# FEI_frontal\183a.jpg
# Neutral
# 32.83399045467377
# FEI_frontal\184a.jpg
# Happy
# 71.60730361938477
# FEI_frontal\185a.jpg
# Neutral
# 59.104740619659424
# FEI_frontal\186a.jpg
# Neutral
# 46.286746859550476
# FEI_frontal\187a.jpg
# Neutral
# 52.76907682418823
# FEI_frontal\188a.jpg
# Neutral
# 56.972575187683105
# FEI_frontal\189a.jpg
# No-Face
# 45.06939649581909
# FEI_frontal\18a.jpg
# Happy
# 55.017054080963135
# FEI_frontal\190a.jpg
# Neutral
# 50.21688938140869
# FEI_frontal\191a.jpg
# Neutral
# 58.2968533039093
# FEI_frontal\192a.jpg
# Neutral
# 34.59606468677521
# FEI_frontal\193a.jpg
# Neutral
# 59.01217460632324
# FEI_frontal\194a.jpg
# Neutral
# 40.3785765171051
# FEI_frontal\195a.jpg
# Happy
# 60.192739963531494
# FEI_frontal\196a.jpg
# No-Face
# 32.93428122997284
# FEI_frontal\197a.jpg
# Neutral
# 50.75086951255798
# FEI_frontal\198a.jpg
# Neutral
# 45.10607719421387
# FEI_frontal\199a.jpg
# Neutral
# 56.35707378387451
# FEI_frontal\19a.jpg
# Happy
# 28.797119855880737
# FEI_frontal\1a.jpg
# Anger
# 37.364181876182556
# FEI_frontal\200a.jpg
# Neutral
# 46.48725390434265
# FEI_frontal\20a.jpg
# Neutral
# 71.21006846427917
# FEI_frontal\21a.jpg
# No-Face
# 57.22085237503052
# FEI_frontal\22a.jpg
# Neutral
# 60.48300266265869
# FEI_frontal\23a.jpg
# Anger
# 51.09647512435913
# FEI_frontal\24a.jpg
# No-Face
# 22.39796817302704
# FEI_frontal\25a.jpg
# Neutral
# 55.280447006225586
# FEI_frontal\26a.jpg
# Neutral
# 49.8665452003479
# FEI_frontal\27a.jpg
# Neutral
# 64.98270630836487
# FEI_frontal\28a.jpg
# Happy
# 58.73606204986572
# FEI_frontal\29a.jpg
# Neutral
# 35.01424491405487
# FEI_frontal\2a.jpg
# Neutral
# 55.6908905506134
# FEI_frontal\30a.jpg
# Happy
# 64.35946226119995
# FEI_frontal\31a.jpg
# Neutral
# 35.962945222854614
# FEI_frontal\32a.jpg
# Neutral
# 61.08766794204712
# FEI_frontal\33a.jpg
# Neutral
# 59.07377004623413
# FEI_frontal\34a.jpg
# Neutral
# 69.06071305274963
# FEI_frontal\35a.jpg
# Neutral
# 41.35007560253143
# FEI_frontal\36a.jpg
# Neutral
# 54.32196855545044
# FEI_frontal\37a.jpg
# Neutral
# 37.75148391723633
# FEI_frontal\38a.jpg
# Happy
# 53.50304841995239
# FEI_frontal\39a.jpg
# Neutral
# 52.6108980178833
# FEI_frontal\3a.jpg
# Neutral
# 34.44765508174896
# FEI_frontal\40a.jpg
# Neutral
# 30.481934547424316
# FEI_frontal\41a.jpg
# No-Face
# 45.754578709602356
# FEI_frontal\42a.jpg
# Happy
# 82.08735585212708
# FEI_frontal\43a.jpg
# Happy
# 29.532381892204285
# FEI_frontal\44a.jpg
# Neutral
# 42.17621982097626
# FEI_frontal\45a.jpg
# Neutral
# 47.36606478691101
# FEI_frontal\46a.jpg
# Neutral
# 53.55404615402222
# FEI_frontal\47a.jpg
# Neutral
# 61.29825711250305
# FEI_frontal\48a.jpg
# Neutral
# 47.37648963928223
# FEI_frontal\49a.jpg
# Neutral
# 43.965405225753784
# FEI_frontal\4a.jpg
# Neutral
# 44.3032830953598
# FEI_frontal\50a.jpg
# Neutral
# 40.33080041408539
# FEI_frontal\51a.jpg
# No-Face
# 44.05943155288696
# FEI_frontal\52a.jpg
# No-Face
# 82.83659219741821
# FEI_frontal\53a.jpg
# Neutral
# 44.27294731140137
# FEI_frontal\54a.jpg
# Neutral
# 42.11359918117523
# FEI_frontal\55a.jpg
# No-Face
# 40.009719133377075
# FEI_frontal\56a.jpg
# Neutral
# 46.37450873851776
# FEI_frontal\57a.jpg
# Neutral
# 39.536017179489136
# FEI_frontal\58a.jpg
# Neutral
# 48.783063888549805
# FEI_frontal\59a.jpg
# Neutral
# 60.19211411476135
# FEI_frontal\5a.jpg
# Neutral
# 48.33270013332367
# FEI_frontal\60a.jpg
# Neutral
# 25.99809169769287
# FEI_frontal\61a.jpg
# No-Face
# 49.00846183300018
# FEI_frontal\62a.jpg
# Happy
# 57.21612572669983
# FEI_frontal\63a.jpg
# Neutral
# 43.32375526428223
# FEI_frontal\64a.jpg
# Neutral
# 54.48024868965149
# FEI_frontal\65a.jpg
# Neutral
# 49.24159348011017
# FEI_frontal\66a.jpg
# Neutral
# 48.63274097442627
# FEI_frontal\67a.jpg
# Neutral
# 58.44808220863342
# FEI_frontal\68a.jpg
# Neutral
# 68.29468607902527
# FEI_frontal\69a.jpg
# Neutral
# 38.43489587306976
# FEI_frontal\6a.jpg
# Neutral
# 31.367123126983643
# FEI_frontal\70a.jpg
# Neutral
# 46.166861057281494
# FEI_frontal\71a.jpg
# Happy
# 59.96290445327759
# FEI_frontal\72a.jpg
# Happy
# 42.432817816734314
# FEI_frontal\73a.jpg
# Neutral
# 37.853455543518066
# FEI_frontal\74a.jpg
# Neutral
# 45.08648216724396
# FEI_frontal\75a.jpg
# No-Face
# 80.36466836929321
# FEI_frontal\76a.jpg
# No-Face
# 37.80970573425293
# FEI_frontal\77a.jpg
# No-Face
# 56.85069561004639
# FEI_frontal\78a.jpg
# Neutral
# 57.75713324546814
# FEI_frontal\79a.jpg
# No-Face
# 42.90069043636322
# FEI_frontal\7a.jpg
# Sad
# 49.3319571018219
# FEI_frontal\80a.jpg
# Neutral
# 47.50116467475891
# FEI_frontal\81a.jpg
# Neutral
# 42.08039045333862
# FEI_frontal\82a.jpg
# No-Face
# 59.089094400405884
# FEI_frontal\83a.jpg
# Neutral
# 57.2689950466156
# FEI_frontal\84a.jpg
# No-Face
# 45.30545175075531
# FEI_frontal\85a.jpg
# Neutral
# 51.647984981536865
# FEI_frontal\86a.jpg
# Neutral
# 53.649717569351196
# FEI_frontal\87a.jpg
# No-Face
# 70.5730140209198
# FEI_frontal\88a.jpg
# Neutral
# 50.53638815879822
# FEI_frontal\89a.jpg
# Neutral
# 59.018921852111816
# FEI_frontal\8a.jpg
# Neutral
# 46.218475699424744
# FEI_frontal\90a.jpg
# Neutral
# 47.877439856529236
# FEI_frontal\91a.jpg
# Neutral
# 50.443702936172485
# FEI_frontal\92a.jpg
# Neutral
# 46.296319365501404
# FEI_frontal\93a.jpg
# Neutral
# 58.707356452941895
# FEI_frontal\94a.jpg
# Neutral
# 40.191903710365295
# FEI_frontal\95a.jpg
# Neutral
# 49.51610267162323
# FEI_frontal\96a.jpg
# Neutral
# 58.47340226173401
# FEI_frontal\97a.jpg
# No-Face
# 58.2694947719574
# FEI_frontal\98a.jpg
# No-Face
# 54.44419980049133
# FEI_frontal\99a.jpg
# No-Face
# 64.7816002368927
# FEI_frontal\9a.jpg
# Neutral
# 44.62756812572479
